# %% [markdown]
# # Лабораторная работа №3
# ## Линейные структуры данных
# ### Связный список
#
# № 1. Возьмите реализацию класса UnorderedList из лекционных материалов и выполните
# следующие доработки:
# 1. Реализуйте оставшиеся методы этого класса append(item), index(item),
# insert(pos,item), pop(), pop(pos). Требования к работе этих методов посмотрите в
# лекционной презентации.
# 2. Реализуйте метод __str__, чтобы содержимое списка отображалось в Python-стиле (в
# квадратных скобках).
# 3. Реализуйте метод “среза”. Он должен принимать два параметра (start и stop) и
# возвращать копию списка, начиная с позиции start и заканчивая (но не включая!)
# позицией stop.
# Все выполненные доработки должны быть протестированы.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

    def getData(self):
        return self.data

    def getNext(self):
        return self.next

    def setData(self, newdata):
        self.data = newdata

    def setNext(self, newnext):
        self.next = newnext

class UnorderedList:
    def __init__(self):
        self.head = None

    def __str__(self):
        current = self.head
        items = []
        while current is not None:
            items.append(repr(current.getData()))
            current = current.getNext()
        return "[" + ", ".join(items) + "]"

    def add(self, item):
        temp = Node(item)
        temp.setNext(self.head)
        self.head = temp

    def remove(self, item):
        current = self.head
        previous = None
        found = False
        while not found:
            if current.getData() == item:
                found = True
            else:
                previous = current
                current = current.getNext()

        if previous == None:
            self.head = current.getNext()
        else:
            previous.setNext(current.getNext())

    def isEmpty(self):
        return self.head == None

    def search(self, item):
        current = self.head
        found = False
        while current != None and not found:
            if current.getData() == item:
                found = True
            else:
                current = current.getNext()

        return found

    def size(self):
        current = self.head
        count = 0
        while current != None:
            count += 1
            current = current.getNext()

        return count

    def append(self, item):
        temp = Node(item)
        if self.head is None:
            self.head = temp
            return

        current = self.head
        while current.getNext() != None:
            current = current.getNext()
        current.setNext(temp)

    def index(self, item):
        current = self.head
        count = 0
        while current is not None:
            if current.getData() == item:
                return count
            count += 1
            current = current.getNext()

    def insert(self, pos, item):
        if pos == 0:
            self.add(item)
            return

        temp = Node(item)
        current = self.head
        previous = None
        count = 0

        while count < pos:
            previous = current
            current = current.getNext()
            count += 1

        previous.setNext(temp)
        temp.setNext(current)


    def pop(self, pos=None):
        if self.isEmpty():
            raise IndexError("Попытка удалить элемент из пустого списка")

        if pos is None:
            pos = self.size() - 1

        if pos == 0:
            item = self.head.getData()
            self.head = self.head.getNext()
            return item

        current = self.head
        previous = None
        count = 0

        while count < pos:
            previous = current
            current = current.getNext()
            count += 1

        if current is None:
            raise IndexError("Индекс вне диапазона")

        item = current.getData()
        if previous:
            previous.setNext(current.getNext())
        else:
            self.head = current.getNext()
        return item


    def slice(self, start, stop):
        result = UnorderedList()
        current = self.head
        count = 0

        while current is not None and count < stop:
            if count >= start:
                result.append(current.getData())
            current = current.getNext()
            count += 1

        return result

mylist = UnorderedList()

mylist.add(31)
mylist.add(71)
mylist.add(17)
mylist.add(93)
mylist.add(26)
mylist.add(54)

print("Список после добавления элементов:", mylist)
print("Размер списка:", mylist.size())
print("Индекс элемента 93:", mylist.index(93))
mylist.insert(2, 42)
print("Список после вставки 42 на позицию 2:", mylist)
popped_item = mylist.pop()
print("Извлечённый элемент (без указания позиции):", popped_item)
print("Список после извлечения элемента:", mylist)
popped_item_pos = mylist.pop(2)
print("Извлечённый элемент (позиция 2):", popped_item_pos)
print("Список после извлечения элемента на позиции 2:", mylist)
sliced_list = mylist.slice(1, 4)
print("Срез списка с позиции 1 по 4:", sliced_list)
# Out:
# Список после добавления элементов: [54, 26, 93, 17, 71, 31]
# Размер списка: 6
# Индекс элемента 93: 2
# Список после вставки 42 на позицию 2: [54, 26, 42, 93, 17, 71, 31]
# Извлечённый элемент (без указания позиции): 31
# Список после извлечения элемента: [54, 26, 42, 93, 17, 71]
# Извлечённый элемент (позиция 2): 42
# Список после извлечения элемента на позиции 2: [54, 26, 93, 17, 71]
# Срез списка с позиции 1 по 4: [26, 93, 17]

# %% [markdown]
# № 2. Напишите функцию move_to_front для чтения строк с клавиатуры и сохранения их в
# связном списке без повторов. Пользователь последовательно вводит с клавиатуры n строк.
# При вводе строки, которая раньше не встречалась, вставьте ее в начало списка. При вводе
# уже внесенной строки удалите ее из списка и снова вставьте в начало.
# Такая функция реализует стратегию «сдвиг в начало», которая применяется в кешировании,
# при сжатии данных и т.д.

# %%
def move_to_front(n):
    mylist_ = UnorderedList()

    for n in range(n):
        line = input()
        if not line:
            break

        if mylist_.search(line):
            mylist_.remove(line)

        mylist_.add(line)

    return mylist_

print(move_to_front(5))
# Out:
# ['4', '3', '2', '1']

# %% [markdown]
# № 3. Напишите функцию, которая принимает в качестве аргумента первый узел односвязного
# списка, обращает порядок элементов списка (с разрушением исходного) и возвращает в
# качестве результата первый узел полученного списка. Разработайте два варианта решения
# этой задачи: 1) итеративный и 2) рекурсивный.

# %%
def reverse_iterative(head):
    current = head
    previous = None

    while current is not None:
        temp = current.next
        current.next = previous
        previous = current
        current = temp
    return previous

def reverse_recursive(head):
    if head is None or head.next is None:
        return head
    temp = reverse_recursive(head.next)
    head.next.next = head
    head.next = None
    return temp

def print_list(head):
    current = head
    result = []
    while current:
        result.append(current.data)
        current = current.next
    print(" -> ".join(map(str, result)))

head = Node(1)
head.next = Node(2)
head.next.next = Node(3)
head.next.next.next = Node(4)
head.next.next.next.next = Node(5)

print("Исходный список:")
print_list(head)

# Итеративное обращение
reversed_head_iterative = reverse_iterative(head)
print("\nСписок после итеративного обращения:")
print_list(reversed_head_iterative)

# Рекурсивное обращение
reversed_head_recursive = reverse_recursive(reversed_head_iterative)
print("\nСписок после рекурсивного обращения:")
print_list(reversed_head_recursive)
# Out:
# Исходный список:
# 1 -> 2 -> 3 -> 4 -> 5
#
# Список после итеративного обращения:
# 5 -> 4 -> 3 -> 2 -> 1
#
# Список после рекурсивного обращения:
# 1 -> 2 -> 3 -> 4 -> 5

# %% [markdown]
# № 4. Используя реализацию связного списка из задания № 1 (класс UnorderedList), реализуйте
# следующие линейные структуры (необходимый набор методов посмотрите в лекционной
# презентации):
# 1. Стек.
# 2. Очередь.
# 3. Дек.
#
# Проведите тестирование реализованных линейных структур.
# Продумайте и проведите показательный эксперимент, сравнивающий производительность
# стека, очереди или дека, основанных на списках Python, с реализациями на основе
# связанного списка. Например, для сравнения можно взять какую-либо операцию
# выбранной линейной структуры.

# %%
class Stack:
    def __init__(self):
        self.items = UnorderedList()

    def isEmpty(self):
        return self.items.isEmpty()

    def push(self, item):
        return self.items.add(item)

    def pop(self):
        return self.items.pop(0)

    def peek(self):
        return self.items.head.getData()

    def size(self):
        return self.items.size()

    def __str__(self):
        return self.items.__str__()

class Queue:
    def __init__(self):
        self.items = UnorderedList()

    def enqueue(self, item):
        self.items.append(item)

    def dequeue(self):
        return self.items.pop(0)

    def isEmpty(self):
        return self.items.isEmpty()

    def size(self):
        return self.items.size()

    def __str__(self):
        return self.items.__str__()
        
class Deque:
    def __init__(self):
        self.items = UnorderedList()

    def addFront(self, item):
        self.items.add(item)

    def addRear(self, item):
        self.items.append(item)

    def removeFront(self):
        self.items.pop()

    def removeRear(self):
        self.items.pop(0)

    def isEmpty(self):
        return self.items.isEmpty()

    def size(self):
        return self.items.size()

    def __str__(self):
        return self.items.__str__()

print("Тест стека:")

stack = Stack()

stack.push(1)
stack.push(2)
stack.push(3)

print(f"Исходный стек: {stack}")
print(f"Пустой: {stack.isEmpty()}")
print(f"Извлечен: {stack.pop()}")
print(f"Стек после извлечения: {stack}")
print(f"Вершина стека: {stack.peek()}")
print(f"Размер стека: {stack.size()}")

print("\nТест очереди:")

queue = Queue()

queue.enqueue(1)
queue.enqueue(2)
queue.enqueue(3)

print(f"Исходная очередь: {queue}")
print(f"Пустая: {queue.isEmpty()}")
print(f"Извлечен: {queue.dequeue()}")
print(f"Очередь после извлечения: {queue}")
print(f"Размер очереди: {queue.size()}")

print("\nТест дека:")
deque = Deque()

deque.addFront(1)
deque.addRear(2)
deque.addFront(0)
deque.addRear(3)

print(f"Исходный дек: {deque}")
deque.removeFront()
print(f"Дек после удаления с фронта: {deque}")
deque.removeRear()
print(f"Дек после удаления с хвоста: {deque}")
print(f"Пустой: {deque.isEmpty()}")
print(f"Размер дека: {deque.size()}")
# Out:
# Тест стека:
# Исходный стек: [3, 2, 1]
# Пустой: False
# Извлечен: 3
# Стек после извлечения: [2, 1]
# Вершина стека: 2
# Размер стека: 2
#
# Тест очереди:
# Исходная очередь: [1, 2, 3]
# Пустая: False
# Извлечен: 1
# Очередь после извлечения: [2, 3]
# Размер очереди: 2
#
# Тест дека:
# Исходный дек: [0, 1, 2, 3]
# Дек после удаления с фронта: [0, 1, 2]
# Дек после удаления с хвоста: [1, 2]
# Пустой: False
# Размер дека: 2

# %%
import time

# Тестирование производительности стека
def test_stack():
    linked_stack = Stack()
    python_stack = []

    # Добавление элементов
    start = time.time()
    for i in range(100000):
        linked_stack.push(i)
    linked_stack_time = time.time() - start

    start = time.time()
    for i in range(100000):
        python_stack.append(i)
    python_stack_time = time.time() - start

    # Удаление элементов
    start = time.time()
    for i in range(100000):
        linked_stack.pop()
    linked_stack_pop_time = time.time() - start

    start = time.time()
    for i in range(100000):
        python_stack.pop()
    python_stack_pop_time = time.time() - start

    print("Стек:")
    print(f"Добавление (связный список): {linked_stack_time:.6f} сек")
    print(f"Добавление (Python список): {python_stack_time:.6f} сек")
    print(f"Удаление (связный список): {linked_stack_pop_time:.6f} сек")
    print(f"Удаление (Python список): {python_stack_pop_time:.6f} сек")

# Запуск тестов
test_stack()
# Out:
# Стек:
# Добавление (связный список): 0.040205 сек
# Добавление (Python список): 0.004862 сек
# Удаление (связный список): 0.022747 сек
# Удаление (Python список): 0.003100 сек

# %% [markdown]
# № 5. Реализуйте класс DoubleList для построения двух связных списков, в которых каждый узел
# содержит ссылку на узел, предшествующий ему в списке, и ссылку на следующий узел.
# Класс должен иметь следующие методы: проверка списка на пустоту, поиск элемента,
# размер списка, вставка в начало, вставка в конец, удаление из начала, удаление из конца,
# вставка перед указанным узлом, вставка после указанного узла, удаление указанного узла.
# Проведите тестирование методов реализованного класса.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None

class DoubleList:
    def __init__(self):
        self.head = None
        self.tail = None

    def isEmpty(self):
        return self.head is None

    def size(self):
        count = 0
        current = self.head
        while current:
            count += 1
            current = current.next
        return count

    def search(self, item):
        current = self.head
        while current:
            if current.data == item:
                return True
            current = current.next
        return False

    def addFront(self, item):
        new_node = Node(item)
        if self.isEmpty():
            self.head = self.tail = new_node
        else:
            new_node.next = self.head
            self.head.prev = new_node
            self.head = new_node

    def addRear(self, item):
        new_node = Node(item)
        if self.isEmpty():
            self.head = self.tail = new_node
        else:
            new_node.prev = self.tail
            self.tail.next = new_node
            self.tail = new_node

    def removeFront(self):
        if self.isEmpty():
            raise IndexError("Попытка удалить элемент из пустого списка")
        data = self.head.data
        if self.head == self.tail:  # Один элемент
            self.head = self.tail = None
        else:
            self.head = self.head.next
            self.head.prev = None
        return data

    def removeRear(self):
        if self.isEmpty():
            raise IndexError("Попытка удалить элемент из пустого списка")
        data = self.tail.data
        if self.head == self.tail:  # Один элемент
            self.head = self.tail = None
        else:
            self.tail = self.tail.prev
            self.tail.next = None
        return data

    def insertBefore(self, target, item):
        if self.isEmpty():
            raise ValueError("Список пуст")
        current = self.head
        while current and current.data != target:
            current = current.next
        if current is None:
            raise ValueError("Элемент не найден")
        new_node = Node(item)
        new_node.next = current
        new_node.prev = current.prev
        if current.prev:
            current.prev.next = new_node
        else:
            self.head = new_node
        current.prev = new_node

    def insertAfter(self, target, item):
        if self.isEmpty():
            raise ValueError("Список пуст")
        current = self.head
        while current and current.data != target:
            current = current.next
        if current is None:
            raise ValueError("Элемент не найден")
        new_node = Node(item)
        new_node.prev = current
        new_node.next = current.next
        if current.next:
            current.next.prev = new_node
        else:
            self.tail = new_node
        current.next = new_node

    def remove(self, item):
        if self.isEmpty():
            raise ValueError("Список пуст")
        current = self.head
        while current and current.data != item:
            current = current.next
        if current is None:
            raise ValueError("Элемент не найден")
        if current.prev:
            current.prev.next = current.next
        else:
            self.head = current.next
        if current.next:
            current.next.prev = current.prev
        else:
            self.tail = current.prev

    def __str__(self):
        result = []
        current = self.head
        while current:
            result.append(repr(current.data))
            current = current.next
        return "[" + ", ".join(result) + "]"

# Тестирование
dl = DoubleList()
dl.addFront(10)
dl.addRear(20)
dl.addFront(5)
dl.addRear(25)
print("Список после добавлений:", dl)

dl.removeFront()
print("После удаления с начала:", dl)

dl.removeRear()
print("После удаления с конца:", dl)

dl.insertBefore(20, 15)
print("После вставки перед 20:", dl)

dl.insertAfter(15, 18)
print("После вставки после 15:", dl)

dl.remove(18)
print("После удаления 18:", dl)

print("Размер списка:", dl.size())
print("Поиск 15:", dl.search(15))
print("Поиск 100:", dl.search(100))
# Out:
# Список после добавлений: [5, 10, 20, 25]
# После удаления с начала: [10, 20, 25]
# После удаления с конца: [10, 20]
# После вставки перед 20: [10, 15, 20]
# После вставки после 15: [10, 15, 18, 20]
# После удаления 18: [10, 15, 20]
# Размер списка: 3
# Поиск 15: True
# Поиск 100: False

# %% [markdown]
# ## Стек
#
# № 6. В HTML у каждого тега существуют открывающая и закрывающая формы, которые должны
# быть сбалансированы, чтобы адекватно описывать веб-документ. Вот пример очень
# простого веб-документа:
#
# ```
# <html>
#     <head>
#         <title>Example</title>
#     </head>
#     <body>
#         <h1>Hello, world</h1>
#     </body>
# </html>
# ```
#
# Напишите программу, которая, используя структуру данных стек, проверит HTML
# документ на соответствие открывающих и закрывающих тегов.
# За основу решения можно взять алгоритм проверки скобочной последовательности из
# лекционных материалов.

# %%
def is_html_balanced(html):
    stack = Stack()
    i = 0

    while i < len(html):
        if html[i] == "<":
            j = html.find(">", i + 1)
            if j == -1:
                return False

            tag = html[i + 1:j]

            if not tag.startswith("/"):
                stack.push(tag)
            else:
                if stack.isEmpty():
                    return False
                top_tag = stack.pop()
                if top_tag != tag[1:]:
                    return False

            i = j
        i += 1

    return stack.isEmpty()

html_code = "<html><head><title>Example</title></head><body><h1>Hello, world</h1></body></html>"
print(is_html_balanced(html_code))
# Out:
# True

# %% [markdown]
# № 7. Стековый калькулятор - это устройство (реальное или виртуальное), которое вычисляет
# значения арифметических выражений, записанных в постфиксной форме (также она носит
# название Обратная польская запись — Википедия (wikipedia.org)). Стековым он называется
# так как действует по следующим правилам: если нам встречается число - мы должны
# поместить его в стек; если знак операции - мы должны достать из стека столько чисел,
# сколько необходимо для выполнения данной операции и выполнить ее.
# Именно так и работает т.н. математический сопроцессор (например, в INtel8086+AMD64)-
# часть ЦП, отвечающая за операции над числами с плавающей запятой.
# Реализуйте стековый калькулятор. Напишите программу, которая читает выражение в
# обратной польской нотации и выводит получившееся значение или пишет, что выражение
# составлено не корректно (если оно некорректно).

# %%
def evaluate_postfix(expression):
    stack = Stack()
    operators = {'+', '-', '*', '/'}

    for token in expression.split():
        if token.isdigit():
            stack.push(int(token))
        elif token in operators:
            if stack.size() < 2:
                return "Некорректное выражение"
            b = stack.pop()
            a = stack.pop()
            if token == '+':
                stack.push(a + b)
            elif token == '-':
                stack.push(a - b)
            elif token == '*':
                stack.push(a * b)
            elif token == '/':
                if b == 0:
                    return "Деление на ноль"
                stack.push(a / b)
        else:
            return "Некорректное выражение"

    if stack.size() != 1:
        return "Некорректное выражение"

    return stack.pop()

# Пример использования
expression = "3 4 + 2 * 7 /"
result = evaluate_postfix(expression)
print(f"Результат: {result}")
# Out:
# Результат: 2.0

# %% [markdown]
# ## Очередь
#
# № 8. Используя структуру данных очередь и пример из лекционных материалов, создайте
# симуляцию ситуации из реальной жизни согласно своему варианту:
#
# 1. ~~Вариант. Машины, стоящие в очереди в мойку.~~
# 2. ~~Вариант. Покупатели в очереди на кассе бакалейного магазина.~~
# 3. Вариант. Самолёты, взлетающие и приземляющиеся на взлётно-посадочную полосу.
# 4. ~~Вариант. Абоненты, звонящие в службу поддержки оператора связи.~~
# 5. ~~Вариант. Студенты, сдающие экзамен преподавателю.~~
#
# Обязательно укажите сделанные вами предположения и предоставьте любые
# вероятностные данные, которые нужно будет рассмотреть в качестве части сценария.

# %%
import random

def simulate_runway(duration):
    takeoff_queue = Queue()
    landing_queue = Queue()
    time_elapsed = 0

    while time_elapsed < duration:
        # С вероятностью 30% добавляем самолёт на посадку
        if random.random() < 0.3:
            landing_queue.enqueue(f"Plane_L{time_elapsed}")
            print(f"Самолёт добавлен в очередь на посадку: Plane_L{time_elapsed}")

        # С вероятностью 20% добавляем самолёт на взлёт
        if random.random() < 0.2:
            takeoff_queue.enqueue(f"Plane_T{time_elapsed}")
            print(f"Самолёт добавлен в очередь на взлёт: Plane_T{time_elapsed}")

        # Обработка взлётно-посадочной полосы
        if not landing_queue.isEmpty():
            plane = landing_queue.dequeue()
            print(f"Самолёт {plane} приземлился.")
        elif not takeoff_queue.isEmpty():
            plane = takeoff_queue.dequeue()
            print(f"Самолёт {plane} взлетел.")
        else:
            print("Взлётно-посадочная полоса свободна.")

        time_elapsed += 1
        time.sleep(0.5)

    print("\nСимуляция завершена.")
    print(f"Оставшиеся самолёты в очереди на посадку: {landing_queue}")
    print(f"Оставшиеся самолёты в очереди на взлёт: {takeoff_queue}")

# Запуск симуляции на 10 секунд
simulate_runway(10)
# Out:
# Взлётно-посадочная полоса свободна.
# Самолёт добавлен в очередь на посадку: Plane_L1
# Самолёт Plane_L1 приземлился.
# Взлётно-посадочная полоса свободна.
# Самолёт добавлен в очередь на посадку: Plane_L3
# Самолёт Plane_L3 приземлился.
# Взлётно-посадочная полоса свободна.
# Взлётно-посадочная полоса свободна.
# Самолёт добавлен в очередь на посадку: Plane_L6
# Самолёт Plane_L6 приземлился.
# Самолёт добавлен в очередь на взлёт: Plane_T7
# Самолёт Plane_T7 взлетел.
# Самолёт добавлен в очередь на посадку: Plane_L8
# Самолёт добавлен в очередь на взлёт: Plane_T8
# Самолёт Plane_L8 приземлился.
# Самолёт Plane_T8 взлетел.
#
# Симуляция завершена.
# Оставшиеся самолёты в очереди на посадку: []
# Оставшиеся самолёты в очереди на взлёт: []
